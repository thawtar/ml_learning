# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
data = np.array([1,2,-1,-4,5])

# %%
mask = data > 0

# %%
mask
# Out:
# array([ True,  True, False, False,  True])

# %%
data[mask]
# Out:
# array([1, 2, 5])

# %%
data[~mask]
# Out:
# array([-1, -4])

# %%
arr = np.arange(20
                )

# %%
arr = arr[(arr>5) & (arr<15)]

# %%
arr
# Out:
# array([ 6,  7,  8,  9, 10, 11, 12, 13, 14])

# %%
labels = np.where(data>0,"pos","neg")
labels
# Out:
# array(['pos', 'pos', 'neg', 'neg', 'pos'], dtype='<U3')

# %%
clipped = np.where(data>0,data,0)
clipped
# Out:
# array([1, 2, 0, 0, 5])

# %%
vec = np.array([1,2,3])

# %%
print(f"Original shape: {vec.shape}")
print(f"Newaxis col: {vec[:,np.newaxis].shape}")
print(f"newaxis row: {vec[np.newaxis,:].shape}")
# Out:
# Original shape: (3,)
# Newaxis col: (3, 1)
# newaxis row: (1, 3)

# %%
mat = np.arange(6).reshape(2,3)
print(mat)
print(mat.T)
# Out:
# [[0 1 2]
#  [3 4 5]]
# [[0 3]
#  [1 4]
#  [2 5]]

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])
print(f"vstack: {np.vstack([a,b])}")
print(f"hstack {np.hstack([a,b])}")
print(f"hstack {np.hstack([b,a])}")
print(f"vstack {np.vstack([b,a])}")
# Out:
# vstack: [[1 2 3]
#  [4 5 6]]
# hstack [1 2 3 4 5 6]
# hstack [4 5 6 1 2 3]
# vstack [[4 5 6]
#  [1 2 3]]
