# %%
import kagglehub
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from tqdm import tqdm

# %%
df = pd.read_csv('imdb_ratings.csv')
df.head()
# Out:
#    Unnamed: 0    titleId                   title  averageRating  numVotes
# 0           0  tt0000001              Carmencita            5.7      1676
# 1           1  tt0000002  Le clown et ses chiens            6.1       208
# 2           2  tt0000003          Pauvre Pierrot            6.5      1404
# 3           3  tt0000004             Un bon bock            6.2       123
# 4           4  tt0000005        Blacksmith Scene            6.2      2200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67408 entries, 0 to 67407
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     67408 non-null  int64
#  1   titleId        67408 non-null  object
#  2   title          67408 non-null  object
#  3   averageRating  67408 non-null  float64
#  4   numVotes       67408 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 2.6+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# titleId          0
# title            0
# averageRating    0
# numVotes         0
# dtype: int64

# %%
df.describe()
# Out:
#          Unnamed: 0  averageRating      numVotes
# count  67408.000000   67408.000000  6.740800e+04
# mean   33703.868947       6.354568  2.408154e+03
# std    19459.561080       1.351718  2.320630e+04
# min        0.000000       1.000000  5.000000e+00
# 25%    16851.750000       5.600000  1.800000e+01
# 50%    33703.500000       6.500000  7.500000e+01
# 75%    50556.250000       7.300000  3.680000e+02
# max    67408.000000      10.000000  1.515727e+06

# %%
top_voted = df.sort_values(by='numVotes',ascending=False).head()
import seaborn as sns
plt.figure(figsize=(12,6))
sns.barplot(
    data=top_voted,
    x="numVotes",
    y="title",
    palette="viridis"
)
plt.title("Top 10 Most Voted Movies")
plt.xlabel("Number of Votes")
plt.ylabel("Movie Title")
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_18888\2571226503.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
highest_rating  = df[df['numVotes']>1000].sort_values(by='averageRating',ascending=False).head(10)

# %%
plt.figure(figsize=(12,6))
sns.barplot(
    data=highest_rating,
    x="averageRating",
    y="title",
    palette="viridis"
)
plt.title("Top 10 Most Rated Movies")
plt.xlabel("Rating")
plt.ylabel("Movie Title")
plt.xlim(9,10)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_18888\4119514812.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
plt.figure(figsize=(12,6))
sns.histplot(df['averageRating'],bins=20,kde=True)
plt.title("Distribution of rating")
plt.xlabel("Rating")
plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize=(12,6))
sns.histplot(df['numVotes'],bins=30,kde=True,log_scale=True)
plt.title("Distribution of votes")
plt.xlabel("Number of Votes")
plt.ylabel("Count")

plt.show()
