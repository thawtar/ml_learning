# %%
import ollama

# %%
# read host from llm.env file
with open('llm.env', 'r') as f:
    host = f.read().strip()

host = host.split('=')[1]
print(f"Using Ollama host: {host}")

client = ollama.Client(host=host)
# Out:
# Using Ollama host: https://symbolistic-rachele-gerundially.ngrok-free.dev

# %%
response = client.chat(
    model="qwen2.5:7b", 
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
    ]
)

# %%
response
# Out:
# ChatResponse(model='qwen2.5:7b', created_at='2026-01-31T11:27:06.97488Z', done=True, done_reason='stop', total_duration=2970467833, load_duration=1225791958, prompt_eval_count=14, prompt_eval_duration=136330750, eval_count=67, eval_duration=1410147622, message=Message(role='assistant', content="Sure, I'd be happy to help! Could you please provide more context or specify what kind of assistance you need? Are you looking for information on a particular topic, need help with a specific problem, or require guidance on a project? The more details you can give me, the better I'll be able to assist you.", thinking=None, images=None, tool_name=None, tool_calls=None), logprobs=None)
